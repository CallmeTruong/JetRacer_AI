# %% [markdown]
# First, create the model. This must match the model used in the interactive training notebook.

# %%
from pathlib import Path
import sys
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
import torch
import torchvision

CATEGORIES = ['apex']

device = torch.device('cuda')
model = torchvision.models.resnet18(pretrained=False)
model.fc = torch.nn.Linear(512, 2 * len(CATEGORIES))
model = model.cuda().eval().half()
# Out:
# d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# Next, load the saved model.  Enter the model path you used to save.

# %%
model.load_state_dict(torch.load('road_following_model.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Finally, execute the cell below to make the racecar move forward, steering the racecar based on the x value of the apex.
#
# Here are some tips,
#
# * If the car wobbles left and right,  lower the steering gain
# * If the car misses turns,  raise the steering gain
# * If the car tends right, make the steering bias more negative (in small increments like -0.05)
# * If the car tends left, make the steering bias more postive (in small increments +0.05)

# %%
from utils import preprocess
import numpy as np
from simulation import CarSimulator


STEERING_GAIN = 0.9
STEERING_BIAS = 0.00

# Reuse existing Car instance or close old environment before creating new one
if 'Car' in globals() and Car is not None:
    try:
        Car.close()
    except Exception:
        pass

Car = CarSimulator()

while True:
    image = Car.value
    image = preprocess(image).half()
    output = model(image).detach().cpu().numpy().flatten()
    x = float(output[0])
    steering = x * STEERING_GAIN + STEERING_BIAS
    Car.run(steering, 0.02)
# Out:
# INFO:gym_donkeycar.core.client:connecting to localhost:9091
# d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\spaces\box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\spaces\box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# INFO:gym_donkeycar.envs.donkey_sim:on need car config
# INFO:gym_donkeycar.envs.donkey_sim:sending car config.
# INFO:gym_donkeycar.envs.donkey_sim:sim started!
# starting DonkeyGym env
# Setting default: start_delay 5.0
# Setting default: max_cte 8.0
# Setting default: frame_skip 1
# Setting default: cam_resolution (120, 160, 3)
# Setting default: log_level 20
# Setting default: host localhost
# Setting default: port 9091
# Setting default: steer_limit 1.0
# Setting default: throttle_min 0.0
# Setting default: throttle_max 1.0
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.000
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.000
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.000
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.002
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.003
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.003
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.004
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.007
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.008
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.008
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.007
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.010
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.013
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.012
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.013
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.013
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.015
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.015
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.017
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.019
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.020
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.021
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.020
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.021
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.022
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.025
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.024
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.024
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.029
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.026
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.030
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.031
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.032
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.034
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.035
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.036
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.037
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.038
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.038
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.040
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.040
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.041
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.042
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.043
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.044
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.045
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.048
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.047
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.051
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.050
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.053
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.053
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.056
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.056
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.058
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.059
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.061
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.062
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.064
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.065
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.067
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.068
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.069
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.071
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.072
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.074
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.076
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.077
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.079
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.080
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.082
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.084
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.085
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.087
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.089
# INFO:simulation:steering=-0.11 | throttle=0.02 | reward=0.090
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.092
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.094
# INFO:simulation:steering=-0.11 | throttle=0.02 | reward=0.096
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.097
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.099
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.101
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.103
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.105
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.106
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.108
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.110
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.112
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.114
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.116
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.118
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.120
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.122
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.124
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.126
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.128
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.130
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.132
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.134
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.136
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.138
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.140
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.142
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.144
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.146
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.148
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.150
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.152
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.155
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.157
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.159
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.161
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.163
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.165
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.167
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.168
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.170
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.171
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.172
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.172
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.173
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.174
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.174
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.175
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.176
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.176
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.177
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.178
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.178
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.179
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.179
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.180
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.181
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.181
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.182
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.182
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.183
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.183
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.184
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.184
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.185
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.185
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.185
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.186
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.186
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.187
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.187
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.188
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.188
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.188
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.189
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.189
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.189
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.190
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.190
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.190
# INFO:simulation:steering=-0.04 | throttle=0.02 | reward=0.191
# INFO:simulation:steering=-0.03 | throttle=0.02 | reward=0.191
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.191
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.192
# INFO:simulation:steering=-0.05 | throttle=0.02 | reward=0.192
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.192
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.191
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.191
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.192
# INFO:simulation:steering=-0.08 | throttle=0.02 | reward=0.192
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.193
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.193
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.194
# INFO:simulation:steering=-0.06 | throttle=0.02 | reward=0.194
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.194
# INFO:simulation:steering=-0.07 | throttle=0.02 | reward=0.195
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.195
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.196
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.196
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.197
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.197
# INFO:simulation:steering=-0.09 | throttle=0.02 | reward=0.197
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.198
# INFO:simulation:steering=-0.10 | throttle=0.02 | reward=0.198
# INFO:simulation:steering=-0.11 | throttle=0.02 | reward=0.198
# INFO:simulation:steering=-0.13 | throttle=0.02 | reward=0.199
# INFO:simulation:steering=-0.12 | throttle=0.02 | reward=0.199
# INFO:simulation:steering=-0.11 | throttle=0.02 | reward=0.194
# INFO:simulation:steering=-0.13 | throttle=0.02 | reward=0.195
# INFO:simulation:steering=-0.13 | throttle=0.02 | reward=0.196
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=0.197
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=0.198
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=0.199
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=0.200
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=0.200
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=0.201
# INFO:simulation:steering=-0.17 | throttle=0.02 | reward=0.202
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.203
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.204
# INFO:simulation:steering=-0.19 | throttle=0.02 | reward=0.205
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.205
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.206
# INFO:simulation:steering=-0.17 | throttle=0.02 | reward=0.207
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.208
# INFO:simulation:steering=-0.19 | throttle=0.02 | reward=0.208
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.209
# INFO:simulation:steering=-0.21 | throttle=0.02 | reward=0.210
# INFO:simulation:steering=-0.19 | throttle=0.02 | reward=0.211
# INFO:simulation:steering=-0.21 | throttle=0.02 | reward=0.211
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.204
# INFO:simulation:steering=-0.21 | throttle=0.02 | reward=0.206
# INFO:simulation:steering=-0.19 | throttle=0.02 | reward=0.207
# INFO:simulation:steering=-0.17 | throttle=0.02 | reward=0.208
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.210
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.211
# INFO:simulation:steering=-0.19 | throttle=0.02 | reward=0.213
# INFO:simulation:steering=-0.19 | throttle=0.02 | reward=0.214
# INFO:simulation:steering=-0.20 | throttle=0.02 | reward=0.215
# INFO:simulation:steering=-0.23 | throttle=0.02 | reward=0.217
# INFO:simulation:steering=-0.26 | throttle=0.02 | reward=0.218
# INFO:simulation:steering=-0.27 | throttle=0.02 | reward=0.219
# INFO:simulation:steering=-0.28 | throttle=0.02 | reward=0.221
# INFO:simulation:steering=-0.29 | throttle=0.02 | reward=0.222
# INFO:simulation:steering=-0.29 | throttle=0.02 | reward=0.223
# INFO:simulation:steering=-0.30 | throttle=0.02 | reward=0.225
# INFO:simulation:steering=-0.32 | throttle=0.02 | reward=0.226
# INFO:simulation:steering=-0.33 | throttle=0.02 | reward=0.227
# INFO:simulation:steering=-0.33 | throttle=0.02 | reward=0.228
# INFO:simulation:steering=-0.31 | throttle=0.02 | reward=0.227
# INFO:simulation:steering=-0.33 | throttle=0.02 | reward=0.226
# INFO:simulation:steering=-0.33 | throttle=0.02 | reward=0.225
# INFO:simulation:steering=-0.34 | throttle=0.02 | reward=0.225
# INFO:simulation:steering=-0.33 | throttle=0.02 | reward=0.224
# INFO:simulation:steering=-0.34 | throttle=0.02 | reward=0.223
# INFO:simulation:steering=-0.35 | throttle=0.02 | reward=0.223
# INFO:simulation:steering=-0.35 | throttle=0.02 | reward=0.222
# INFO:simulation:steering=-0.34 | throttle=0.02 | reward=0.229
# INFO:simulation:steering=-0.34 | throttle=0.02 | reward=0.230
# INFO:simulation:steering=-0.36 | throttle=0.02 | reward=0.229
# INFO:simulation:steering=-0.36 | throttle=0.02 | reward=0.227
# INFO:simulation:steering=-0.35 | throttle=0.02 | reward=0.226
# INFO:simulation:steering=-0.36 | throttle=0.02 | reward=0.225
# INFO:simulation:steering=-0.38 | throttle=0.02 | reward=0.223
# INFO:simulation:steering=-0.39 | throttle=0.02 | reward=0.222
# INFO:simulation:steering=-0.40 | throttle=0.02 | reward=0.221
# INFO:simulation:steering=-0.39 | throttle=0.02 | reward=0.219
# INFO:simulation:steering=-0.39 | throttle=0.02 | reward=0.218
# INFO:simulation:steering=-0.40 | throttle=0.02 | reward=0.217
# INFO:simulation:steering=-0.39 | throttle=0.02 | reward=0.216
# INFO:simulation:steering=-0.41 | throttle=0.02 | reward=0.215
# INFO:simulation:steering=-0.41 | throttle=0.02 | reward=0.213
# INFO:simulation:steering=-0.43 | throttle=0.02 | reward=0.212
# INFO:simulation:steering=-0.43 | throttle=0.02 | reward=0.211
# INFO:simulation:steering=-0.44 | throttle=0.02 | reward=0.210
# INFO:simulation:steering=-0.45 | throttle=0.02 | reward=0.208
# INFO:simulation:steering=-0.45 | throttle=0.02 | reward=0.207
# INFO:simulation:steering=-0.44 | throttle=0.02 | reward=0.206
# INFO:simulation:steering=-0.46 | throttle=0.02 | reward=0.205
# INFO:simulation:steering=-0.46 | throttle=0.02 | reward=0.204
# INFO:simulation:steering=-0.47 | throttle=0.02 | reward=0.203
# INFO:simulation:steering=-0.45 | throttle=0.02 | reward=0.202
# INFO:simulation:steering=-0.45 | throttle=0.02 | reward=0.201
# INFO:simulation:steering=-0.43 | throttle=0.02 | reward=0.200
# INFO:simulation:steering=-0.43 | throttle=0.02 | reward=0.199
# INFO:simulation:steering=-0.43 | throttle=0.02 | reward=0.198
# INFO:simulation:steering=-0.44 | throttle=0.02 | reward=0.197
# INFO:simulation:steering=-0.43 | throttle=0.02 | reward=0.195
# INFO:simulation:steering=-0.43 | throttle=0.02 | reward=0.195
# INFO:simulation:steering=-0.42 | throttle=0.02 | reward=0.194
# INFO:simulation:steering=-0.42 | throttle=0.02 | reward=0.207
# INFO:simulation:steering=-0.44 | throttle=0.02 | reward=0.205
# INFO:simulation:steering=-0.45 | throttle=0.02 | reward=0.204
# INFO:simulation:steering=-0.45 | throttle=0.02 | reward=0.202
# INFO:simulation:steering=-0.44 | throttle=0.02 | reward=0.200
# INFO:simulation:steering=-0.44 | throttle=0.02 | reward=0.198
# INFO:simulation:steering=-0.46 | throttle=0.02 | reward=0.197
# INFO:simulation:steering=-0.46 | throttle=0.02 | reward=0.195
# INFO:simulation:steering=-0.46 | throttle=0.02 | reward=0.193
# INFO:simulation:steering=-0.45 | throttle=0.02 | reward=0.192
# INFO:simulation:steering=-0.43 | throttle=0.02 | reward=0.190
# INFO:simulation:steering=-0.41 | throttle=0.02 | reward=0.188
# INFO:simulation:steering=-0.41 | throttle=0.02 | reward=0.187
# INFO:simulation:steering=-0.41 | throttle=0.02 | reward=0.185
# INFO:simulation:steering=-0.41 | throttle=0.02 | reward=0.184
# INFO:simulation:steering=-0.39 | throttle=0.02 | reward=0.182
# INFO:simulation:steering=-0.38 | throttle=0.02 | reward=0.180
# INFO:simulation:steering=-0.38 | throttle=0.02 | reward=0.179
# INFO:simulation:steering=-0.37 | throttle=0.02 | reward=0.177
# INFO:simulation:steering=-0.36 | throttle=0.02 | reward=0.176
# INFO:simulation:steering=-0.36 | throttle=0.02 | reward=0.174
# INFO:simulation:steering=-0.36 | throttle=0.02 | reward=0.173
# INFO:simulation:steering=-0.35 | throttle=0.02 | reward=0.171
# INFO:simulation:steering=-0.35 | throttle=0.02 | reward=0.169
# INFO:simulation:steering=-0.35 | throttle=0.02 | reward=0.168
# INFO:simulation:steering=-0.34 | throttle=0.02 | reward=0.166
# INFO:simulation:steering=-0.33 | throttle=0.02 | reward=0.165
# INFO:simulation:steering=-0.31 | throttle=0.02 | reward=0.163
# INFO:simulation:steering=-0.30 | throttle=0.02 | reward=0.162
# INFO:simulation:steering=-0.25 | throttle=0.02 | reward=0.160
# INFO:simulation:steering=-0.24 | throttle=0.02 | reward=0.159
# INFO:simulation:steering=-0.25 | throttle=0.02 | reward=0.158
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.156
# INFO:simulation:steering=-0.20 | throttle=0.02 | reward=0.155
# INFO:simulation:steering=-0.18 | throttle=0.02 | reward=0.153
# INFO:simulation:steering=-0.19 | throttle=0.02 | reward=0.152
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=0.150
# INFO:simulation:steering=-0.20 | throttle=0.02 | reward=0.149
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.147
# INFO:simulation:steering=-0.23 | throttle=0.02 | reward=0.146
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.144
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.167
# INFO:simulation:steering=-0.23 | throttle=0.02 | reward=0.165
# INFO:simulation:steering=-0.25 | throttle=0.02 | reward=0.163
# INFO:simulation:steering=-0.26 | throttle=0.02 | reward=0.160
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.158
# INFO:simulation:steering=-0.24 | throttle=0.02 | reward=0.156
# INFO:simulation:steering=-0.25 | throttle=0.02 | reward=0.153
# INFO:simulation:steering=-0.25 | throttle=0.02 | reward=0.151
# INFO:simulation:steering=-0.24 | throttle=0.02 | reward=0.149
# INFO:simulation:steering=-0.23 | throttle=0.02 | reward=0.146
# INFO:simulation:steering=-0.24 | throttle=0.02 | reward=0.144
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.142
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.139
# INFO:simulation:steering=-0.22 | throttle=0.02 | reward=0.137
# INFO:simulation:steering=-0.20 | throttle=0.02 | reward=0.135
# INFO:simulation:steering=-0.20 | throttle=0.02 | reward=0.132
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.17 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.14 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.16 | throttle=0.02 | reward=-1.000
# INFO:simulation:steering=-0.15 | throttle=0.02 | reward=-1.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 24
#      20     image = preprocess(image).half()
#      21     output = model(image).detach().cpu().numpy().flatten()
#      22     x = float(output[0])
#      23     steering = x * STEERING_GAIN + STEERING_BIAS
# ---> 24     Car.run(steering, 0.02)
#
# File d:\JetRacer_AI\simulate\simulation.py:31, in CarSimulator.run(self, steering, throttle)
#      29 def run(self, steering, throttle):
#      30     action = np.array([steering, throttle])
# ---> 31     results = self.env.step(action)
#      32     if self.verbose:
#      33         self.logger.info(
#      34             "steering=%.2f | throttle=%.2f | reward=%.3f",
#      35             steering,
#      36             throttle,
#      37             results[1]
#      38         )
#
# File d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\gym_donkeycar\envs\donkey_env.py:138, in DonkeyEnv.step(self, action)
#     136 for _ in range(self.frame_skip):
#     137     self.viewer.take_action(action)
# --> 138     observation, reward, done, info = self.viewer.observe()
#     139 # Gymnasium step returns (observation, reward, terminated, truncated, info)
#     140 # 'done' from the simulator represents termination (collision, out of bounds)
#     141 # truncated is always False as this env doesn't implement time-based truncation
#     142 return observation, reward, done, False, info
#
# File d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\gym_donkeycar\envs\donkey_sim.py:109, in DonkeyUnitySimContoller.observe(self)
#     108 def observe(self) -> Tuple[np.ndarray, float, bool, Dict[str, Any]]:
# --> 109     return self.handler.observe()
#
# File d:\Users\nhatt\AppData\Local\Programs\Python\Python314\Lib\site-packages\gym_donkeycar\envs\donkey_sim.py:436, in DonkeyUnitySimHandler.observe(self)
#     434 def observe(self) -> Tuple[np.ndarray, float, bool, Dict[str, Any]]:
#     435     while self.last_received == self.time_received:
# --> 436         time.sleep(0.001)
#     438     self.last_received = self.time_received
#     439     observation = self.image_array
#
# KeyboardInterrupt:
# INFO:gym_donkeycar.envs.donkey_sim:on need car config
# INFO:gym_donkeycar.envs.donkey_sim:sending car config.
# INFO:gym_donkeycar.envs.donkey_sim:on need car config
# INFO:gym_donkeycar.envs.donkey_sim:sending car config.
# INFO:gym_donkeycar.envs.donkey_sim:on need car config
# INFO:gym_donkeycar.envs.donkey_sim:sending car config.
# INFO:gym_donkeycar.envs.donkey_sim:on need car config
# INFO:gym_donkeycar.envs.donkey_sim:sending car config.
